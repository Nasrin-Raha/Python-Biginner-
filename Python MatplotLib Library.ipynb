# %% [markdown]
# # MatplotLib is an open source drawing library which supports rich drawing types and used to draw 2D and 3D graphics

# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.24.3

# %%
"""
import numpy to generate random data
"""
import numpy as np

x = np.linspace(0,10,25)
y = x * x +2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
print(np.array([x,y]).reshape(25,2))
# Out:
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
#  [  9.16666667   9.58333333]
#  [ 10.           2.        ]
#  [  2.17361111   2.69444444]
#  [  3.5625       4.77777778]
#  [  6.34027778   8.25      ]
#  [ 10.50694444  13.11111111]
#  [ 16.0625      19.36111111]
#  [ 23.00694444  27.        ]
#  [ 31.34027778  36.02777778]
#  [ 41.0625      46.44444444]
#  [ 52.17361111  58.25      ]
#  [ 64.67361111  71.44444444]
#  [ 78.5625      86.02777778]
#  [ 93.84027778 102.        ]]

# %%
print(np.array([x,y]).reshape(25,2).reshape(2,25))
# Out:
# [[  0.           0.41666667   0.83333333   1.25         1.66666667
#     2.08333333   2.5          2.91666667   3.33333333   3.75
#     4.16666667   4.58333333   5.           5.41666667   5.83333333
#     6.25         6.66666667   7.08333333   7.5          7.91666667
#     8.33333333   8.75         9.16666667   9.58333333  10.        ]
#  [  2.           2.17361111   2.69444444   3.5625       4.77777778
#     6.34027778   8.25        10.50694444  13.11111111  16.0625
#    19.36111111  23.00694444  27.          31.34027778  36.02777778
#    41.0625      46.44444444  52.17361111  58.25        64.67361111
#    71.44444444  78.5625      86.02777778  93.84027778 102.        ]]

# %%
"""
It only takes one command to draw
"""

pylab.plot(x,y, "r") # r stands for red or b stands for blue

# %%
"""Drawing a subgraph
"""

pylab.subplot(1,2,1) # The content of the btackets contains (rows, columns, indexes)
pylab.plot(x,y, "r--") # the third parameter here determines color and line style
pylab.subplot(1,2,2)
pylab.plot(y,x, "g*-")

# %%
# 1,2,1 and 1,2,2 are significat



pylab.subplot(1,2,1) # The content of the btackets contains (rows, columns, indexes)
pylab.plot(x,y, "r--") # the third parameter here determines color and line style
pylab.subplot(1,2,1)
pylab.plot(y,x, "g*-")

# %% [markdown]
# # Operator Description
#
# fig.add_axes() = initializes subplot a = fig.add_subplot(222)
# fig, b = plt.subplots(nrows = 3, nclos = 2) = Adds subplot
# ax = plt.subplots(2,2) = creates subplots

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()

axis = fig.add_axes([0.5,0.1,0.8,0.8])
axis.plot(x, y, "r")

# %%
# again we can draw subgraphs

# %%
fig, axes = plt.subplots(nrows =1, ncols =2)
for ax in axes:
    ax.plot(x,y, "r")

# %%
# we can also draw a picture, or a graph inside another graph

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,"r")
axes2.plot(y,x,"g")

# %%
fig = plt.figure(figsize = (16,9), dpi = 300)
fig.add_subplot()
plt.plot(x, y, "r")

# %%
ax.legend(["label1","label2"])
fig, axes = plt.subplots(dpi = 200)
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("title of graph")
axes.plot(x, x**2)
axes.plot(x, x**3)
axes.legend(["y= x**2", "y = x**3"], loc = 2)

# %%
# in matplotlib we can also add other properties such as line color,transparency and more

# %%
fig, axes = plt.subplots(dpi = 150)
axes.plot(x, x**2, color = "r", alpha = .5)
axes.plot(x, x+2, color = "blue", alpha = .8)
axes.plot(x, x+3, color = "green", alpha = .8)

# %%
fig, ax = plt.subplots(dpi = 100)

ax.plot(x, x+1, color ="blue", marker = "o")
ax.plot(x, x+2, color ="blue", marker = "+")
ax.plot(x, x+3, color ="blue", marker = "s")
ax.plot(x, x+4, color ="blue", marker = "1")
ax.plot(x, x+5, color ="blue", marker = "o", markersize = 3)
ax.plot(x, x+6, color ="blue", marker = "s", markerfacecolor = "red")
ax.plot(x, x+7, color ="blue", marker = "o", markersize = 15, markerfacecolor = "green")

# %%
# set the canvas grid and axis range

# %%
fig, axes = plt.subplots(1,2, figsize = (10,5))
axes[0].plot(x, x**2, x, x**3, lw =2)
axes[0].grid(True)

axes[1].plot(x, x**2, x, x**3, lw = 2)
axes[1].set_ylim([0,60])
axes[1].set_xlim([2,5])
# Out:
# (2.0, 5.0)

# %% [markdown]
# # Other 2D graphics

# %%
n = np.array([0,1,2,3,4,5])
fig, axes = plt.subplots(1,4, figsize = (16,5))
axes[0].set_title("Scatter Plot")
axes[0].scatter(x, x+ 0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2, lw = 2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, align = "center", alpha =0.5)

axes[3].set_title("fill_between")
axes[3].fill_between(x, x**2, x**3, color = "green", alpha =0.5)

# %%
"""Draw a radar chart
"""

fig = plt.figure(figsize =(6,6))
ax = fig.add_axes([0.0,0.0,.6,.6], polar = True)
t = np.linspace(0, 2* np.pi, 100)
ax.plot(t,t*2, color ="blue", lw=3)

# %%
"""Draw a histogram
"""

n = np.random.randn(100000)
fig, axes = plt.subplots(1,2, figsize =(12,4))
axes[0].set_title("Histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed Histogram")
axes[1].hist(n, cumulative = True, bins = 10)
# Out:
# (array([1.4000e+01, 2.7400e+02, 3.0720e+03, 1.6492e+04, 4.7038e+04,
#         7.9578e+04, 9.5566e+04, 9.9526e+04, 9.9967e+04, 1.0000e+05]),
#  array([-4.54716765, -3.65241729, -2.75766694, -1.86291658, -0.96816623,
#         -0.07341587,  0.82133448,  1.71608484,  2.61083519,  3.50558555,
#          4.4003359 ]),
#  <BarContainer object of 10 artists>)

# %%
"""Draw contour image
"""

import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0,3.0, delta)
y = np.arange(-2.0,2.0, delta)
X, Y = np.meshgrid(x, y)

Z1 = np.exp(-X**2, - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y-1)**2)
Z = (Z1 - Z2)*2

print(X)
print(Y)


fig, ax = plt.subplots()
CS = ax.contour(X,Y,Z)
ax.clabel(CS, inline =1, fontsize = 10)
ax.set_title("contour map")
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]
# Text(0.5, 1.0, 'contour map')
